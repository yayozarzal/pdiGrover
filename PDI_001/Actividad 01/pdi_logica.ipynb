# %% [markdown]
# Ejercicios Lógica python

# %% [markdown]
# 1. Desarrolle una aplicación que calcule el factorial de un numero entero introducido por
# teclado

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)

numero = int(input("Introduce un numero entero: "))
print(f"El factorial de {numero} es {factorial(numero)}")

# %% [markdown]
# 2. Desarrolle una aplicación que determine si un numero introducido por teclado es primo o
# no

# %%
def es_primo(n):
    if n <= 1:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

numero = int(input("Introduce un número entero: "))
if es_primo(numero):
    print(f"{numero} es un número primo")
else:
    print(f"{numero} no es un número primo")
# Out:
# 14 no es un número primo

# %% [markdown]
# 3.- Desarrolle una aplicación que permita ingresar diferentes números por teclado con un limite
# definido inicialmente (no menor a 3 números) y determine cual de ellos es el mayor y el menor.

# %%
def mayor_menor():
    cantidad = int(input("Introduce la cantidad de números (no menor a 3): "))
    if cantidad < 3:
        print("La cantidad debe ser al menos 3")
        return
    
    numeros = []
    for i in range(cantidad):
        numero = float(input(f"Introduce el número {i+1}: "))
        numeros.append(numero)
    
    mayor = max(numeros)
    menor = min(numeros)
    
    print(f"El número mayor es {mayor}")
    print(f"El número menor es {menor}")

mayor_menor()
# Out:
# El número mayor es 8.0
# El número menor es 2.0

# %% [markdown]
# 5.- desarrolle una aplicación que permita introducir 7 números por teclado y determine cual de
# ellos se repite más veces y cuantas.

# %%
def numero_mas_repetido():
    numeros = []
    for i in range(7):
        numero = int(input(f"Introduce el número {i+1}: "))
        numeros.append(numero)
    
    frecuencia = {}
    for numero in numeros:
        if numero in frecuencia:
            frecuencia[numero] += 1
        else:
            frecuencia[numero] = 1
    
    numero_repetido = max(frecuencia, key=frecuencia.get)
    veces_repetido = frecuencia[numero_repetido]
    
    print(f"El número que más se repite es {numero_repetido} y se repite {veces_repetido} veces")

numero_mas_repetido()
# Out:
# El número que más se repite es 2 y se repite 2 veces

# %% [markdown]
#  Desarrolle una aplicación que permita identificar si una cadena introducida por teclado es
# un palíndromo ( oso es palíndromo )

# %%
def es_palindromo(cadena):
    cadena = cadena.replace(" ", "").lower()
    return cadena == cadena[::-1]

cadena = input("Introduce una cadena: ")
if es_palindromo(cadena):
    print(f"'{cadena}' es un palíndromo")
else:
    print(f"'{cadena}' no es un palíndromo")
# Out:
# 'tresert' es un palíndromo
